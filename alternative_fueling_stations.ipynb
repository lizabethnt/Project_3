# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
alternative_fueling_stations_read = "Resources/alternative_fueling_stations.xlsx"
alternative_fueling_stations = pd.read_excel(alternative_fueling_stations_read)
alternative_fueling_stations_df = pd.DataFrame(alternative_fueling_stations)
alternative_fueling_stations_df.head()
alternative_fueling_stations_df.count()
# Out:
# OBJECTID                 82470
# access_code              82469
# access_days_time         73904
# access_detail_code        7945
# date_last_confirmed      82299
# fuel_type_code           82470
# maximum_vehicle_class    20083
# open_date                82178
# facility_type            29474
# station_name             82469
# city                     82422
# country                  82470
# state                    82470
# street_address           82389
# zip                      82426
# longitude                82470
# latitude                 82470
# dtype: int64

# %%
alternative_fueling_stations_df2 = alternative_fueling_stations_df.dropna()
alternative_fueling_stations_df2.head(5)
# Out:
#    OBJECTID access_code                                   access_days_time  \
# 3         4      public                                     24 hours daily
# 4         5      public  24 hours daily; call 866-809-4869 for Clean En...
# 5         6      public  24 hours daily; call 866-809-4869 for Clean En...
# 6         7      public  24 hours daily; call 866-809-4869 for Clean En...
# 7         8      public  24 hours daily; call 866-809-4869 for Clean En...
#
#    access_detail_code date_last_confirmed fuel_type_code  \
# 3  CREDIT_CARD_ALWAYS          2023-08-10            CNG
# 4  CREDIT_CARD_ALWAYS          2023-09-14            CNG
# 5  CREDIT_CARD_ALWAYS          2023-12-13            CNG
# 6  CREDIT_CARD_ALWAYS          2023-09-14            CNG
# 7  CREDIT_CARD_ALWAYS          2024-01-09            CNG
#
#   maximum_vehicle_class  open_date       facility_type  \
# 3                    MD 1997-01-01             UTILITY
# 4                    MD 1996-11-15             AIRPORT
# ...

# %%
alternative_fueling_stations_df3 = alternative_fueling_stations_df.drop('access_days_time', axis='columns')
alternative_fueling_stations_df3.head(5)
# Out:
#    OBJECTID access_code  access_detail_code date_last_confirmed  \
# 0         1     private                 NaN          2023-04-06
# 1         2     private          GOVERNMENT          2024-02-12
# 2         3     private                 NaN          2023-12-13
# 3         4      public  CREDIT_CARD_ALWAYS          2023-08-10
# 4         5      public  CREDIT_CARD_ALWAYS          2023-09-14
#
#   fuel_type_code maximum_vehicle_class  open_date       facility_type  \
# 0            CNG                    MD 2010-12-01  STANDALONE_STATION
# 1            CNG                    LD 1996-12-15        FLEET_GARAGE
# 2            CNG                    HD 1997-01-01  STANDALONE_STATION
# 3            CNG                    MD 1997-01-01             UTILITY
# 4            CNG                    MD 1996-11-15             AIRPORT
#
#                                    station_name         city country state  \
# 0          Spire - Montgomery Operations Center   Montgomery      US    AL
# ...

# %%
alternative_fueling_stations_df3.notnull()
# Out:
#        OBJECTID  access_code  access_detail_code  date_last_confirmed  \
# 0          True         True               False                 True
# 1          True         True                True                 True
# 2          True         True               False                 True
# 3          True         True                True                 True
# 4          True         True                True                 True
# ...         ...          ...                 ...                  ...
# 82465      True         True               False                 True
# 82466      True         True               False                 True
# 82467      True         True               False                 True
# 82468      True         True               False                 True
# 82469      True         True               False                 True
#
#        fuel_type_code  maximum_vehicle_class  open_date  facility_type  \
# ...

# %%
alternative_fueling_stations_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82470 entries, 0 to 82469
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   OBJECTID               82470 non-null  int64
#  1   access_code            82469 non-null  object
#  2   access_detail_code     7945 non-null   object
#  3   date_last_confirmed    82299 non-null  datetime64[ns]
#  4   fuel_type_code         82470 non-null  object
#  5   maximum_vehicle_class  20083 non-null  object
#  6   open_date              82178 non-null  datetime64[ns]
#  7   facility_type          29474 non-null  object
#  8   station_name           82469 non-null  object
#  9   city                   82422 non-null  object
#  10  country                82470 non-null  object
#  11  state                  82470 non-null  object
#  12  street_address         82389 non-null  object
#  13  zip                    82426 non-null  object
# ...

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy import desc

# %%
engine = create_engine("sqlite:///Resources/fueling_stations.sqlite")

# %%
Base = automap_base()
# reflect the tables
Base.prepare(autoload_with=engine)

# %%
Base.classes.keys()
# Out:
# []

# %%
alternative_fueling_stations_df3.to_sql('alternative_fueling_stations', engine, if_exists='replace', index=False)
# Out:
# 82470

# %%
Base.classes.keys()
# Out:
# []

# %%
pd.read_sql_table('alternative_fueling_stations', con=engine)
# Out:
#        OBJECTID access_code  access_detail_code date_last_confirmed  \
# 0             1     private                None          2023-04-06
# 1             2     private          GOVERNMENT          2024-02-12
# 2             3     private                None          2023-12-13
# 3             4      public  CREDIT_CARD_ALWAYS          2023-08-10
# 4             5      public  CREDIT_CARD_ALWAYS          2023-09-14
# ...         ...         ...                 ...                 ...
# 82465     82466      public                None          2024-04-03
# 82466     82467      public                None          2024-04-03
# 82467     82468      public                None          2024-04-03
# 82468     82469      public                None          2024-04-03
# 82469     82470      public                None          2024-04-03
#
#       fuel_type_code maximum_vehicle_class  open_date       facility_type  \
# 0                CNG                    MD 2010-12-01  STANDALONE_STATION
# ...
